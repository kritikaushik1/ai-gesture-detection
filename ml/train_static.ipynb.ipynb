# %%
from google.colab import drive

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

print(os.listdir("/content/drive/MyDrive")[:10])
# Out:
# ['Can', 'Cam', 'IMG20241002192004.jpg', 'Screenshot_2024-11-09-22-34-51-15_944a2809ea1b4cda6ef12d1db9048ed3.jpg', 'Screenshot_2024-11-10-19-12-49-28_944a2809ea1b4cda6ef12d1db9048ed3.jpg', 'Screenshot_2024-11-12-17-20-28-24_944a2809ea1b4cda6ef12d1db9048ed3.jpg', 'Kriti Aktu form.pdf', '2025-08-02 14-03-51_compressed_copy (1).pdf', '2025-08-02 14-03-51_compressed_copy.pdf', 'Screenshot_2025-08-22-16-47-25-87_944a2809ea1b4cda6ef12d1db9048ed3.jpg']

# %%
import os

PROJECT_PATH = "/content/drive/MyDrive/AI_Gesture_Gaming/ml"

os.makedirs(PROJECT_PATH, exist_ok=True)

print("Project folder created successfully")
print(PROJECT_PATH)
# Out:
# Project folder created successfully
# /content/drive/MyDrive/AI_Gesture_Gaming/ml

# %%
# !pip install -q kagglehub

# %%
import kagglehub

DATASET_PATH = kagglehub.dataset_download(
    "gti-upm/leapgestrecog"
)

print("Dataset Path:")
print(DATASET_PATH)
# Out:
# Using Colab cache for faster access to the 'leapgestrecog' dataset.
# Dataset Path:
# /kaggle/input/leapgestrecog

# %%
# !pip install -q kagglehub

import kagglehub
import os

# Download or locate LeapGestRecog dataset
DATASET_PATH = kagglehub.dataset_download(
    "gti-upm/leapgestrecog"
)

print("Dataset downloaded/found at:")
print(DATASET_PATH)

# Select only one copy of the dataset
IMAGE_DATASET_PATH = os.path.join(
    DATASET_PATH,
    "leapGestRecog"
)

print("\nImage Dataset Path:")
print(IMAGE_DATASET_PATH)

# Find subject folders
subjects = sorted([
    folder
    for folder in os.listdir(IMAGE_DATASET_PATH)
    if os.path.isdir(
        os.path.join(IMAGE_DATASET_PATH, folder)
    )
])

print("\nSubjects:")
print(subjects)

print("\nTotal Subjects:", len(subjects))
# Out:
# Using Colab cache for faster access to the 'leapgestrecog' dataset.
# Dataset downloaded/found at:
# /kaggle/input/leapgestrecog
#
# Image Dataset Path:
# /kaggle/input/leapgestrecog/leapGestRecog
#
# Subjects:
# ['00', '01', '02', '03', '04', '05', '06', '07', '08', '09']
#
# Total Subjects: 10

# %%
for folder in ["leapGestRecog", "leapgestrecog"]:
    folder_path = os.path.join(DATASET_PATH, folder)

    print("\nFOLDER:", folder)
    print("Contents:", os.listdir(folder_path)[:20])
# Out:
# FOLDER: leapGestRecog
# Contents: ['07', '05', '06', '02', '04', '00', '08', '09', '03', '01']
#
# FOLDER: leapgestrecog
# Contents: ['leapGestRecog']

# %%
for folder in ["leapGestRecog", "leapgestrecog"]:
    folder_path = os.path.join(DATASET_PATH, folder)

    total_images = 0

    for root, dirs, files in os.walk(folder_path):
        total_images += len([
            file for file in files
            if file.lower().endswith((".png", ".jpg", ".jpeg"))
        ])

    print(folder, ":", total_images, "images")
# Out:
# leapGestRecog : 20000 images
# leapgestrecog : 20000 images

# %%
IMAGE_DATASET_PATH = os.path.join(
    DATASET_PATH,
    "leapGestRecog"
)

print(IMAGE_DATASET_PATH)
# Out:
# /kaggle/input/leapgestrecog/leapGestRecog

# %%
subjects = sorted(os.listdir(IMAGE_DATASET_PATH))

print("Subjects:")
print(subjects)

print("Total Subjects:", len(subjects))
# Out:
# Subjects:
# ['00', '01', '02', '03', '04', '05', '06', '07', '08', '09']
# Total Subjects: 10

# %%
for subject in subjects:
    subject_path = os.path.join(
        IMAGE_DATASET_PATH,
        subject
    )

    gestures = sorted(os.listdir(subject_path))

    print(subject, "->", gestures)
# Out:
# 00 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 01 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 02 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 03 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 04 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 05 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 06 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 07 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# ...

# %%
for subject in subjects:
    subject_path = os.path.join(
        IMAGE_DATASET_PATH,
        subject
    )

    gestures = sorted(os.listdir(subject_path))

    print(subject, "->", gestures)
# Out:
# 00 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 01 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 02 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 03 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 04 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 05 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 06 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# 07 -> ['01_palm', '02_l', '03_fist', '04_fist_moved', '05_thumb', '06_index', '07_ok', '08_palm_moved', '09_c', '10_down']
# ...

# %%
from collections import defaultdict

class_counts = defaultdict(int)

for subject in subjects:
    subject_path = os.path.join(
        IMAGE_DATASET_PATH,
        subject
    )

    for gesture in os.listdir(subject_path):
        gesture_path = os.path.join(
            subject_path,
            gesture
        )

        images = [
            file for file in os.listdir(gesture_path)
            if file.lower().endswith(
                (".png", ".jpg", ".jpeg")
            )
        ]

        class_counts[gesture] += len(images)

for gesture, count in sorted(class_counts.items()):
    print(f"{gesture}: {count}")

print("\nTotal Images:", sum(class_counts.values()))
# Out:
# 01_palm: 2000
# 02_l: 2000
# 03_fist: 2000
# 04_fist_moved: 2000
# 05_thumb: 2000
# 06_index: 2000
# 07_ok: 2000
# 08_palm_moved: 2000
# 09_c: 2000
# 10_down: 2000
#
# Total Images: 20000

# %%
import os
import cv2
import matplotlib.pyplot as plt

sample_subject = subjects[0]

subject_path = os.path.join(
    IMAGE_DATASET_PATH,
    sample_subject
)

gesture_folders = sorted([
    folder
    for folder in os.listdir(subject_path)
    if os.path.isdir(os.path.join(subject_path, folder))
])

plt.figure(figsize=(15, 8))

for index, gesture in enumerate(gesture_folders):

    gesture_path = os.path.join(
        subject_path,
        gesture
    )

    image_files = sorted([
        file
        for file in os.listdir(gesture_path)
        if file.lower().endswith((".png", ".jpg", ".jpeg"))
    ])

    image_path = os.path.join(
        gesture_path,
        image_files[0]
    )

    image = cv2.imread(
        image_path,
        cv2.IMREAD_GRAYSCALE
    )

    plt.subplot(2, 5, index + 1)

    plt.imshow(image, cmap="gray")
    plt.title(gesture)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# !pip install -q mediapipe

# %%
import mediapipe as mp

print("MediaPipe Version:", mp.__version__)
print("MediaPipe Tasks Available:", hasattr(mp, "tasks"))
# Out:
# MediaPipe Version: 0.10.35
# MediaPipe Tasks Available: True

# %%
# !wget -q \
https://storage.googleapis.com/mediapipe-models/hand_landmarker/hand_landmarker/float16/latest/hand_landmarker.task \
-O /content/hand_landmarker.task

print("Model downloaded")
# Out:
# Model downloaded

# %%
import os

MODEL_PATH = "/content/hand_landmarker.task"

print("Model exists:", os.path.exists(MODEL_PATH))
print("Model size:", os.path.getsize(MODEL_PATH))
# Out:
# Model exists: True
# Model size: 7819105

# %%
import os
import cv2
import mediapipe as mp

MODEL_PATH = "/content/hand_landmarker.task"

BaseOptions = mp.tasks.BaseOptions
HandLandmarker = mp.tasks.vision.HandLandmarker
HandLandmarkerOptions = mp.tasks.vision.HandLandmarkerOptions
VisionRunningMode = mp.tasks.vision.RunningMode

options = HandLandmarkerOptions(
    base_options=BaseOptions(
        model_asset_path=MODEL_PATH
    ),
    running_mode=VisionRunningMode.IMAGE,
    num_hands=1,
    min_hand_detection_confidence=0.3,
    min_hand_presence_confidence=0.3
)

tested = 0
detected = 0
failed = 0

with HandLandmarker.create_from_options(options) as landmarker:

    for subject in subjects:

        subject_path = os.path.join(
            IMAGE_DATASET_PATH,
            subject
        )

        for gesture in sorted(os.listdir(subject_path)):

            gesture_path = os.path.join(
                subject_path,
                gesture
            )

            image_files = sorted(os.listdir(gesture_path))

            # Test 10 images from every gesture
            for image_name in image_files[:10]:

                image_path = os.path.join(
                    gesture_path,
                    image_name
                )

                image = cv2.imread(image_path)

                if image is None:
                    failed += 1
                    continue

                rgb_image = cv2.cvtColor(
                    image,
                    cv2.COLOR_BGR2RGB
                )

                mp_image = mp.Image(
                    image_format=mp.ImageFormat.SRGB,
                    data=rgb_image
                )

                result = landmarker.detect(mp_image)

                tested += 1

                if result.hand_landmarks:
                    detected += 1

                if tested >= 100:
                    break

            if tested >= 100:
                break

        if tested >= 100:
            break

print("Images Tested:", tested)
print("Hands Detected:", detected)
print("Hands Not Detected:", tested - detected)

detection_rate = (detected / tested) * 100

print(f"Detection Rate: {detection_rate:.2f}%")
# Out:
# Images Tested: 100
# Hands Detected: 32
# Hands Not Detected: 68
# Detection Rate: 32.00%

# %%
# !git clone -b kriti-ml https://github.com/kritikaushik1/ai-gesture-detection.git
# Out:
# Cloning into 'ai-gesture-detection'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 15 (delta 2), reused 14 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 896.95 KiB | 10.68 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
import pandas as pd

CSV_PATH = "/content/ai-gesture-detection/data/static_landmarks.csv"

df = pd.read_csv(CSV_PATH)

print("Dataset loaded successfully")
print("Shape:", df.shape)

df.head()
# Out:
# Dataset loaded successfully
# Shape: (1750, 64)
#    landmark_0_x  landmark_0_y  landmark_0_z  landmark_1_x  landmark_1_y  \
# 0           0.0           0.0           0.0     -0.272737     -0.078627
# 1           0.0           0.0           0.0     -0.278247     -0.071193
# 2           0.0           0.0           0.0     -0.282090     -0.091202
# 3           0.0           0.0           0.0     -0.289157     -0.124697
# 4           0.0           0.0           0.0     -0.289841     -0.112347
#
#    landmark_1_z  landmark_2_x  landmark_2_y  landmark_2_z  landmark_3_x  ...  \
# 0     -0.048211     -0.503839     -0.373890     -0.069710     -0.542639  ...
# 1     -0.065102     -0.514097     -0.347353     -0.098691     -0.541694  ...
# 2     -0.067957     -0.513347     -0.374297     -0.103258     -0.506945  ...
# 3     -0.039636     -0.504382     -0.401075     -0.069244     -0.522035  ...
# 4     -0.043138     -0.529309     -0.382274     -0.069191     -0.591406  ...
#
# ...

# %%
# Clean column names
df.columns = df.columns.str.strip()

print("Shape:", df.shape)

print("\nMissing Values:")
print(df.isnull().sum().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())

print("\nClass Distribution:")
print(df["gesture_label"].value_counts())

print("\nData Types:")
print(df.dtypes.value_counts())
# Out:
# Shape: (1750, 64)
#
# Missing Values:
# 0
#
# Duplicate Rows:
# 0
#
# Class Distribution:
# gesture_label
# fist     250
# peace    250
# thumb    250
# point    250
# ok       250
# rock     250
# open     250
# Name: count, dtype: int64
#
# Data Types:
# float64    63
# object      1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Separate features and labels
X = df.drop("gesture_label", axis=1)
y = df["gesture_label"]

print("Feature Shape:", X.shape)
print("Label Shape:", y.shape)

# Encode gesture labels
label_encoder = LabelEncoder()

y_encoded = label_encoder.fit_transform(y)

print("\nGesture Classes:")
print(label_encoder.classes_)

print("\nEncoded Labels:")
for index, gesture in enumerate(label_encoder.classes_):
    print(f"{gesture} -> {index}")
# Out:
# Feature Shape: (1750, 63)
# Label Shape: (1750,)
#
# Gesture Classes:
# ['fist' 'ok' 'open' 'peace' 'point' 'rock' 'thumb']
#
# Encoded Labels:
# fist -> 0
# ok -> 1
# open -> 2
# peace -> 3
# point -> 4
# rock -> 5
# thumb -> 6

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_encoded,
    test_size=0.20,
    random_state=42,
    stratify=y_encoded
)

print("Training Features:", X_train.shape)
print("Testing Features:", X_test.shape)

print("Training Labels:", y_train.shape)
print("Testing Labels:", y_test.shape)
# Out:
# Training Features: (1400, 63)
# Testing Features: (350, 63)
# Training Labels: (1400,)
# Testing Labels: (350,)

# %%
# !pip install -q xgboost

# %%
from xgboost import XGBClassifier

print("XGBoost imported successfully")
# Out:
# XGBoost imported successfully

# %%
model = XGBClassifier(
    objective="multi:softprob",
    num_class=len(label_encoder.classes_),
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    random_state=42,
    eval_metric="mlogloss"
)

print(model)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None, num_class=7, ...)

# %%
model.fit(
    X_train,
    y_train
)

print("Model training completed")
# Out:
# Model training completed

# %%
y_pred = model.predict(X_test)

print("Predictions completed")
print("First 10 predictions:", y_pred[:10])
print("First 10 actual labels:", y_test[:10])
# Out:
# Predictions completed
# First 10 predictions: [4 5 0 1 4 1 5 2 4 2]
# First 10 actual labels: [4 5 0 1 4 1 5 2 4 2]

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

accuracy = accuracy_score(y_test, y_pred)

precision = precision_score(
    y_test,
    y_pred,
    average="weighted"
)

recall = recall_score(
    y_test,
    y_pred,
    average="weighted"
)

f1 = f1_score(
    y_test,
    y_pred,
    average="weighted"
)

print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")

print("\nClassification Report:\n")

print(
    classification_report(
        y_test,
        y_pred,
        target_names=label_encoder.classes_
    )
)
# Out:
# Accuracy  : 0.9771
# Precision : 0.9777
# Recall    : 0.9771
# F1 Score  : 0.9772
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         fist       1.00      1.00      1.00        50
#           ok       0.96      0.98      0.97        50
#         open       1.00      0.94      0.97        50
#        peace       0.96      0.96      0.96        50
#        point       0.92      0.96      0.94        50
#         rock       1.00      1.00      1.00        50
#        thumb       1.00      1.00      1.00        50
#
#     accuracy                           0.98       350
#    macro avg       0.98      0.98      0.98       350
# weighted avg       0.98      0.98      0.98       350

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(
    y_test,
    y_pred
)

display = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=label_encoder.classes_
)

display.plot(
    xticks_rotation=45
)

plt.title("Static Gesture Recognition Confusion Matrix")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [3, 5, 7],
    "learning_rate": [0.05, 0.1]
}

base_model = XGBClassifier(
    objective="multi:softprob",
    num_class=len(label_encoder.classes_),
    random_state=42,
    eval_metric="mlogloss"
)

grid_search = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid,
    cv=3,
    scoring="f1_weighted",
    n_jobs=-1,
    verbose=1
)

grid_search.fit(X_train, y_train)

print("Best Parameters:")
print(grid_search.best_params_)

print("\nBest CV Score:")
print(grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# Best Parameters:
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}
#
# Best CV Score:
# 0.9699865747637721

# %%
best_model = grid_search.best_estimator_

y_pred_tuned = best_model.predict(X_test)

print("Tuned model predictions completed")
# Out:
# Tuned model predictions completed

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

tuned_accuracy = accuracy_score(y_test, y_pred_tuned)

tuned_precision = precision_score(
    y_test,
    y_pred_tuned,
    average="weighted"
)

tuned_recall = recall_score(
    y_test,
    y_pred_tuned,
    average="weighted"
)

tuned_f1 = f1_score(
    y_test,
    y_pred_tuned,
    average="weighted"
)

print(f"Accuracy  : {tuned_accuracy:.4f}")
print(f"Precision : {tuned_precision:.4f}")
print(f"Recall    : {tuned_recall:.4f}")
print(f"F1 Score  : {tuned_f1:.4f}")

print("\nClassification Report:\n")

print(
    classification_report(
        y_test,
        y_pred_tuned,
        target_names=label_encoder.classes_
    )
)
# Out:
# Accuracy  : 0.9800
# Precision : 0.9804
# Recall    : 0.9800
# F1 Score  : 0.9801
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         fist       1.00      1.00      1.00        50
#           ok       0.98      0.98      0.98        50
#         open       1.00      0.96      0.98        50
#        peace       0.96      0.96      0.96        50
#        point       0.92      0.96      0.94        50
#         rock       1.00      1.00      1.00        50
#        thumb       1.00      1.00      1.00        50
#
#     accuracy                           0.98       350
#    macro avg       0.98      0.98      0.98       350
# weighted avg       0.98      0.98      0.98       350

# %%
import os
import joblib

ML_PATH = "/content/ai-gesture-detection/ml"

os.makedirs(ML_PATH, exist_ok=True)

MODEL_PATH = os.path.join(
    ML_PATH,
    "static_model.pkl"
)

ENCODER_PATH = os.path.join(
    ML_PATH,
    "label_encoder.pkl"
)

joblib.dump(
    best_model,
    MODEL_PATH
)

joblib.dump(
    label_encoder,
    ENCODER_PATH
)

print("Model saved:", MODEL_PATH)
print("Label Encoder saved:", ENCODER_PATH)
# Out:
# Model saved: /content/ai-gesture-detection/ml/static_model.pkl
# Label Encoder saved: /content/ai-gesture-detection/ml/label_encoder.pkl

# %%
loaded_model = joblib.load(MODEL_PATH)
loaded_encoder = joblib.load(ENCODER_PATH)

test_predictions = loaded_model.predict(X_test)

print("Model loaded successfully")
print("Classes:", loaded_encoder.classes_)

print(
    "Reloaded Model Accuracy:",
    accuracy_score(y_test, test_predictions)
)
# Out:
# Model loaded successfully
# Classes: ['fist' 'ok' 'open' 'peace' 'point' 'rock' 'thumb']
# Reloaded Model Accuracy: 0.98

# %%
predict_code = '''
import os
import joblib
import numpy as np
import pandas as pd


BASE_DIR = os.path.dirname(os.path.abspath(__file__))

MODEL_PATH = os.path.join(BASE_DIR, "static_model.pkl")
ENCODER_PATH = os.path.join(BASE_DIR, "label_encoder.pkl")


model = joblib.load(MODEL_PATH)
label_encoder = joblib.load(ENCODER_PATH)


def normalize_landmarks(landmarks):
    if len(landmarks) != 21:
        raise ValueError("Exactly 21 hand landmarks are required")

    wrist_x, wrist_y, wrist_z = landmarks[0]

    normalized = []

    for x, y, z in landmarks:
        normalized.extend([
            x - wrist_x,
            y - wrist_y,
            z - wrist_z
        ])

    scale = max(abs(value) for value in normalized)

    if scale == 0:
        raise ValueError("Invalid landmarks: scale is zero")

    return [
        value / scale
        for value in normalized
    ]


def get_feature_names():
    columns = []

    for landmark_id in range(21):
        columns.extend([
            f"landmark_{landmark_id}_x",
            f"landmark_{landmark_id}_y",
            f"landmark_{landmark_id}_z"
        ])

    return columns


def predict_gesture(landmarks):
    features = normalize_landmarks(landmarks)

    input_data = pd.DataFrame(
        [features],
        columns=get_feature_names()
    )

    probabilities = model.predict_proba(input_data)[0]

    predicted_index = int(np.argmax(probabilities))

    gesture = label_encoder.inverse_transform(
        [predicted_index]
    )[0]

    confidence = float(probabilities[predicted_index])

    return {
        "gesture": gesture,
        "confidence": round(confidence, 4)
    }
'''

PREDICT_PATH = "/content/ai-gesture-detection/ml/predict.py"

with open(PREDICT_PATH, "w") as file:
    file.write(predict_code)

print("predict.py created successfully")
# Out:
# predict.py created successfully

# %%
with open(PREDICT_PATH, "r") as file:
    print(file.read())
# Out:
# import os
# import joblib
# import numpy as np
# import pandas as pd
#
#
# BASE_DIR = os.path.dirname(os.path.abspath(__file__))
#
# MODEL_PATH = os.path.join(BASE_DIR, "static_model.pkl")
# ENCODER_PATH = os.path.join(BASE_DIR, "label_encoder.pkl")
#
#
# model = joblib.load(MODEL_PATH)
# label_encoder = joblib.load(ENCODER_PATH)
#
#
# def normalize_landmarks(landmarks):
#     if len(landmarks) != 21:
#         raise ValueError("Exactly 21 hand landmarks are required")
#
#     wrist_x, wrist_y, wrist_z = landmarks[0]
#
#     normalized = []
#
#     for x, y, z in landmarks:
#         normalized.extend([
#             x - wrist_x,
#             y - wrist_y,
#             z - wrist_z
#         ])
#
#     scale = max(abs(value) for value in normalized)
#
#     if scale == 0:
#         raise ValueError("Invalid landmarks: scale is zero")
#
#     return [
#         value / scale
#         for value in normalized
#     ]
#
#
# def get_feature_names():
#     columns = []
#
# ...

# %%
import sys

sys.path.append(
    "/content/ai-gesture-detection/ml"
)

from predict import predict_gesture


sample_features = X.iloc[0].values

landmarks = sample_features.reshape(21, 3).tolist()

result = predict_gesture(landmarks)

print("Actual Gesture:", y.iloc[0])
print("Prediction Result:", result)
# Out:
# Actual Gesture: fist
# Prediction Result: {'gesture': 'fist', 'confidence': 0.9926}

# %%
import shutil
import os

SOURCE_CSV = "/content/ai-gesture-detection/data/static_landmarks.csv"
ML_CSV = "/content/ai-gesture-detection/ml/static_landmarks.csv"

shutil.copy2(SOURCE_CSV, ML_CSV)

print("CSV copied successfully")
print(os.path.exists(ML_CSV))
# Out:
# CSV copied successfully
# True

# %%
retrain_code = '''
import os
import joblib
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier


BASE_DIR = os.path.dirname(os.path.abspath(__file__))

CSV_PATH = os.path.join(BASE_DIR, "static_landmarks.csv")
MODEL_PATH = os.path.join(BASE_DIR, "static_model.pkl")
ENCODER_PATH = os.path.join(BASE_DIR, "label_encoder.pkl")


def load_dataset():
    df = pd.read_csv(CSV_PATH)

    df.columns = df.columns.str.strip()

    return df


def append_new_samples(new_csv_path):
    old_df = load_dataset()

    new_df = pd.read_csv(new_csv_path)

    new_df.columns = new_df.columns.str.strip()

    if list(old_df.columns) != list(new_df.columns):
        raise ValueError(
            "New CSV columns do not match training dataset"
        )

    combined_df = pd.concat(
        [old_df, new_df],
        ignore_index=True
    )

    combined_df = combined_df.dropna()
    combined_df = combined_df.drop_duplicates()

    combined_df.to_csv(
        CSV_PATH,
        index=False
    )

    print("New samples appended successfully")
    print("Total Samples:", len(combined_df))

    return combined_df


def train_model(df):
    X = df.drop(
        "gesture_label",
        axis=1
    )

    y = df["gesture_label"]

    label_encoder = LabelEncoder()

    y_encoded = label_encoder.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(
        X,
        y_encoded,
        test_size=0.20,
        random_state=42,
        stratify=y_encoded
    )

    model = XGBClassifier(
        objective="multi:softprob",
        num_class=len(label_encoder.classes_),
        learning_rate=0.05,
        max_depth=5,
        n_estimators=200,
        random_state=42,
        eval_metric="mlogloss"
    )

    model.fit(
        X_train,
        y_train
    )

    predictions = model.predict(X_test)

    accuracy = accuracy_score(
        y_test,
        predictions
    )

    print("Retraining completed")
    print("Accuracy:", round(accuracy, 4))
    print("Gesture Classes:", label_encoder.classes_)

    joblib.dump(
        model,
        MODEL_PATH
    )

    joblib.dump(
        label_encoder,
        ENCODER_PATH
    )

    print("Updated model saved")
    print("Updated label encoder saved")


def retrain(new_csv_path=None):
    if new_csv_path is not None:
        df = append_new_samples(
            new_csv_path
        )
    else:
        df = load_dataset()

    train_model(df)


if __name__ == "__main__":
    retrain()
'''

RETRAIN_PATH = "/content/ai-gesture-detection/ml/retrain.py"

with open(RETRAIN_PATH, "w") as file:
    file.write(retrain_code)

print("retrain.py created successfully")
# Out:
# retrain.py created successfully

# %%
import sys

sys.path.append(
    "/content/ai-gesture-detection/ml"
)

from retrain import retrain

retrain()
# Out:
# Retraining completed
# Accuracy: 0.98
# Gesture Classes: ['fist' 'ok' 'open' 'peace' 'point' 'rock' 'thumb']
# Updated model saved
# Updated label encoder saved

# %%
readme_code = """
# AI Gesture Gaming Platform - Static Gesture ML

## Overview

This module performs static hand gesture recognition using MediaPipe hand landmarks and XGBoost.

## Pipeline

Webcam
→ MediaPipe
→ 21 Hand Landmarks
→ 63 Features (x, y, z)
→ Landmark Normalization
→ XGBoost
→ Gesture Prediction

## Supported Gestures

- fist
- ok
- open
- peace
- point
- rock
- thumb

## Model Performance

Accuracy: 98.00%
Precision: 98.04%
Recall: 98.00%
F1 Score: 98.01%

## Files

- static_landmarks.csv: Training landmark dataset
- static_model.pkl: Trained XGBoost model
- label_encoder.pkl: Gesture label encoder
- predict.py: Gesture prediction interface
- retrain.py: Future custom gesture retraining pipeline
- train_static.ipynb: Model training notebook

## Prediction Output

Example:

{
    "gesture": "fist",
    "confidence": 0.9926
}

## Custom Gesture Retraining

New gesture landmark samples must follow the same 63-feature format.

Use:

retrain("new_gesture.csv")

The pipeline appends new samples, retrains XGBoost, and saves an updated model and label encoder.

## Important

The same landmark normalization used during dataset collection must be used during real-time prediction.
"""

README_PATH = "/content/ai-gesture-detection/ml/README.md"

with open(README_PATH, "w") as file:
    file.write(readme_code)

print("README.md created successfully")
# Out:
# README.md created successfully

# %%
import os

ML_PATH = "/content/ai-gesture-detection/ml"

for file in os.listdir(ML_PATH):
    print(file)
# Out:
# retrain.py
# predict.py
# static_model.pkl
# __pycache__
# label_encoder.pkl
# README.md
# static_landmarks.csv

# %%
import shutil

shutil.make_archive(
    "/content/ml_files",
    "zip",
    "/content/ai-gesture-detection/ml"
)

print("ZIP created successfully")
# Out:
# ZIP created successfully

# %%
from google.colab import files

files.download("/content/ml_files.zip")
